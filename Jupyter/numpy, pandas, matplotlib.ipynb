# %%
import matplotlib.pyplot as plt #question1
import numpy as np #question2
import pandas as pd 
file=open('../data/housing.csv','r')
df=pd.read_csv(file) #df for data frame

# %%
size=df.size #question5
print(size)
# Out:
# 206400

# %%
data_types=df.dtypes #question6
print(data_types)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# median_house_value      int64
# ocean_proximity        object
# dtype: object

# %%
dimensions=df.shape #question7
print(dimensions)
# Out:
# (20640, 10)

# %%
file_info=df.info() #questions5-7 consolidated (could get size by mult rangeIndex by Data Columns)
print(file_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null int64
# total_rooms           20640 non-null int64
# total_bedrooms        20433 non-null float64
# population            20640 non-null int64
# households            20640 non-null int64
# median_income         20640 non-null float64
# median_house_value    20640 non-null int64
# ocean_proximity       20640 non-null object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB
# None

# %%
#skewed right
#not shown - outliers 10000 and greater, cutoff display at 16000
#oultiers will be shown in scatter later on
population=df['population']
plt.hist([population],bins=50,range=[0,16000],rwidth=.55,color=['blue'])
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.title('Population Analysis')
plt.show()

# %%
df['ocean_proximity'].value_counts().plot(kind='bar');
plt.xlabel('Proximity')
plt.ylabel('Count')
plt.title('Count of Proximity')
plt.show()

# %%
x=df['housing_median_age']
y=df['population']
price=df['median_house_value']
plt.xlabel('age')
plt.ylabel('pop')
plt.title('Scatter Plot')
cm = plt.cm.get_cmap('RdYlBu')
scatter=plt.scatter(x,y,c=price,cmap=cm)
plt.colorbar(scatter)
plt.show()
def scatter_description():
    '''
There is a strong, negative, somewhat linear relationship
between increase in age and population. Reference the color scale
on the side to see the relationship with price.There seems to be 
know clear correlation between the price of homes and age, but maybe 
slighlt higher prices homes in lowerpopulations(note - around 5000 
there sees to be a cluster of blue).There are some significant oultiers 
in 'pop'. For example, notice the 35000 and 29000 ranges. 

    '''
print(scatter_description.__doc__)
# Out:
# There is a strong, negative, somewhat linear relationship
# between increase in age and population. Reference the color scale
# on the side to see the relationship with price.There seems to be
# know clear correlation between the price of homes and age, but maybe
# slighlt higher prices homes in lowerpopulations(note - around 5000
# there sees to be a cluster of blue).There are some significant oultiers
# in 'pop'. For example, notice the 35000 and 29000 ranges.
